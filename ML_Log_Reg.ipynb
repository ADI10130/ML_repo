# %% [markdown]
# <a href="https://colab.research.google.com/github/ADI10130/ML_repo/blob/main/ML_Log_Reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning: Logistic Regression on Iris Dataset
# ### By: Aditya Arvikar

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
import sklearn.metrics as metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

# %%
df = pd.read_csv('/content/Iris.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['Species']=df['Species'].replace({'Iris-setosa':1, 'Iris-versicolor':2, 'Iris-virginica':3})
# Out:
# <ipython-input-13-b0659d577101>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Species']=df['Species'].replace({'Iris-setosa':1, 'Iris-versicolor':2, 'Iris-virginica':3})

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        1
# 1      2            4.9           3.0            1.4           0.2        1
# 2      3            4.7           3.2            1.3           0.2        1
# 3      4            4.6           3.1            1.5           0.2        1
# 4      5            5.0           3.6            1.4           0.2        1
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        3
# 146  147            6.3           2.5            5.0           1.9        3
# 147  148            6.5           3.0            5.2           2.0        3
# 148  149            6.2           3.4            5.4           2.3        3
# 149  150            5.9           3.0            5.1           1.8        3
#
# [150 rows x 6 columns]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']],df['Species'], test_size = 0.2)

# %%
X_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 135            7.7           3.0            6.1           2.3
# 118            7.7           2.6            6.9           2.3
# 64             5.6           2.9            3.6           1.3
# 16             5.4           3.9            1.3           0.4
# 69             5.6           2.5            3.9           1.1
# ..             ...           ...            ...           ...
# 109            7.2           3.6            6.1           2.5
# 27             5.2           3.5            1.5           0.2
# 19             5.1           3.8            1.5           0.3
# 122            7.7           2.8            6.7           2.0
# 119            6.0           2.2            5.0           1.5
#
# [120 rows x 4 columns]

# %%
Y_train
# Out:
# 135    3
# 118    3
# 64     2
# 16     1
# 69     2
#       ..
# 109    3
# 27     1
# 19     1
# 122    3
# 119    3
# Name: Species, Length: 120, dtype: int64

# %%
log_reg = LogisticRegression(max_iter=120) #since 120 rows to be itr
log_reg.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=120)

# %%
log_reg.predict(X_test)
# Out:
# array([2, 1, 2, 2, 3, 2, 1, 1, 3, 1, 3, 1, 2, 2, 2, 1, 2, 1, 1, 3, 1, 1,
#        2, 3, 1, 2, 2, 1, 1, 2])

# %%
X_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 81             5.5           2.4            3.7           1.0
# 28             5.2           3.4            1.4           0.2
# 75             6.6           3.0            4.4           1.4
# 82             5.8           2.7            3.9           1.2
# 141            6.9           3.1            5.1           2.3
# 73             6.1           2.8            4.7           1.2
# 6              4.6           3.4            1.4           0.3
# 48             5.3           3.7            1.5           0.2
# 142            5.8           2.7            5.1           1.9
# 25             5.0           3.0            1.6           0.2
# 116            6.5           3.0            5.5           1.8
# 2              4.7           3.2            1.3           0.2
# 59             5.2           2.7            3.9           1.4
# 79             5.7           2.6            3.5           1.0
# 58             6.6           2.9            4.6           1.3
# 3              4.6           3.1            1.5           0.2
# 50             7.0           3.2            4.7           1.4
# 42             4.4           3.2            1.3           0.2
# 30             4.8           3.1            1.6           0.2
# 114            5.8           2.8            5.1           2.4
# 9              4.9           3.1            1.5           0.1
# 29             4.7           3.2            1.6           0.2
# 60             5.0           2.0            3.5           1.0
# 70             5.9           3.2            4.8           1.8
# 41             4.5           2.3            1.3           0.3
# 95             5.7           3.0            4.2           1.2
# 94             5.6           2.7            4.2           1.3
# 0              5.1           3.5            1.4           0.2
# 36             5.5           3.5            1.3           0.2
# 80             5.5           2.4            3.8           1.1

# %%
log_reg.score(X_test, Y_test)
# Out:
# 0.9666666666666667

# %%
Y_pred = log_reg.predict(X_test)
Y_pred
# Out:
# array([2, 1, 2, 2, 3, 2, 1, 1, 3, 1, 3, 1, 2, 2, 2, 1, 2, 1, 1, 3, 1, 1,
#        2, 3, 1, 2, 2, 1, 1, 2])

# %%
cm = confusion_matrix(Y_test,Y_pred)
cm
# Out:
# array([[13,  0,  0],
#        [ 0, 12,  1],
#        [ 0,  0,  4]])

# %%
plt.figure(figsize = (5,4))
sns.heatmap(cm, annot =True)
plt.xlabel('Predicted Value')
plt.ylabel('Truth or Actual Value')
# Out:
# Text(33.22222222222222, 0.5, 'Truth or Actual Value')

# %%
print("Accuracy of log_reg: ", accuracy_score(Y_test,Y_pred))
print("Precision of log reg: ", precision_score(Y_test, Y_pred, average="weighted"))
print('F1 score of log_reg: ', f1_score(Y_test, Y_pred, average="weighted"))
print("Report of log_reg: ", metrics.classification_report(Y_test, Y_pred))
# Out:
# Accuracy of log_reg:  0.9666666666666667
# Precision of log reg:  0.9733333333333333
# F1 score of log_reg:  0.9678518518518519
# Report of log_reg:                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        13
#            2       1.00      0.92      0.96        13
#            3       0.80      1.00      0.89         4
#
#     accuracy                           0.97        30
#    macro avg       0.93      0.97      0.95        30
# weighted avg       0.97      0.97      0.97        30
